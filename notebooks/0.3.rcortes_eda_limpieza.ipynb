# %% [markdown]
# # EDA limpieza de datos

# %%
#Importar librerias de manipulación de datos
import numpy as np
import pandas as pd

# importar librerías del sistema
import os
from pathlib import Path #para traer las rutas

root_dir=Path(".").resolve().parent #Directorio_raiz
print('root_dir:', root_dir)

filename ="llamadas123_julio_2022.csv"
data_dir = "raw" #directorio del archivo

filepath = os.path.join(root_dir, "data", data_dir, filename)

print(filepath)

data = pd.read_csv(filepath, encoding='latin-1', sep=';') #leer el archivo en la ruta
data.head() # mostrar la cabecera de la tabla
# Out:
# root_dir: C:\Users\Robert Cortes\ESEITBigData2022B
# C:\Users\Robert Cortes\ESEITBigData2022B\data\raw\llamadas123_julio_2022.csv
#   NUMERO_INCIDENTE FECHA_INICIO_DESPLAZAMIENTO_MOVIL  CODIGO_LOCALIDAD  \
# 0  CRU-00278353-22               2022-07-01 00:08:59                11
# 1  CRU-00278360-22               2022-07-01 00:14:58                11
# 2  CRU-00278365-22               2022-07-01 00:21:59                18
# 3  CRU-00278370-22               2022-07-01 00:38:38                19
# 4  CRU-00278372-22               2022-07-01 00:53:32                 1
#
#             LOCALIDAD      EDAD    UNIDAD     GENERO             RED  \
# 0                Suba        88      A¤os   FEMENINO           Norte
# 1                Suba        16      A¤os  MASCULINO           Norte
# 2  Rafael Uribe Uribe        52      A¤os   FEMENINO  Centro Oriente
# 3      Ciudad Bol¡var  SIN_DATO  SIN_DATO   SIN_DATO         Privada
# ...

# %% [markdown]
# # Registros Duplicados

# %%
print('Forma inicial', data.shape)

data= data.drop_duplicates() # Elimina los registro duplicados, dejando solo el primer registro

print('Forma final', data.shape)
# Out:
# Forma inicial (13055, 11)
# Forma final (13026, 11)

# %%
# Esquema de la tabla
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13026 entries, 0 to 13054
# Data columns (total 11 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   NUMERO_INCIDENTE                   13026 non-null  object
#  1   FECHA_INICIO_DESPLAZAMIENTO_MOVIL  13026 non-null  object
#  2   CODIGO_LOCALIDAD                   13026 non-null  int64
#  3   LOCALIDAD                          13026 non-null  object
#  4   EDAD                               13026 non-null  object
#  5   UNIDAD                             13018 non-null  object
#  6   GENERO                             13026 non-null  object
#  7   RED                                13026 non-null  object
#  8   TIPO_INCIDENTE                     13026 non-null  object
#  9   PRIORIDAD                          13026 non-null  object
#  10  RECEPCION                          13026 non-null  object
# dtypes: int64(1), object(10)
# ...

# %%
data['UNIDAD'].value_counts(dropna=False) #Conteo de los valores sin eliminarme lo nulos
# Out:
# A¤os        6781
# SIN_DATO    6187
# Meses         39
# NaN            8
# Horas          6
# Dias           5
# Name: UNIDAD, dtype: int64

# %%
# Reemplace en la columna UNIDAD los nulos por SIN_DATO
data['UNIDAD'].fillna('SIN_DATO').value_counts(dropna=False)
# Out:
# A¤os        6781
# SIN_DATO    6195
# Meses         39
# Horas          6
# Dias           5
# Name: UNIDAD, dtype: int64

# %%
data['UNIDAD'] = data['UNIDAD'].fillna('SIN_DATO')
#Sobreescribo la columna UNIDAD que tenia valores nulos por una columna nueva sin nulos

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13026 entries, 0 to 13054
# Data columns (total 11 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   NUMERO_INCIDENTE                   13026 non-null  object
#  1   FECHA_INICIO_DESPLAZAMIENTO_MOVIL  13026 non-null  object
#  2   CODIGO_LOCALIDAD                   13026 non-null  int64
#  3   LOCALIDAD                          13026 non-null  object
#  4   EDAD                               13026 non-null  object
#  5   UNIDAD                             13026 non-null  object
#  6   GENERO                             13026 non-null  object
#  7   RED                                13026 non-null  object
#  8   TIPO_INCIDENTE                     13026 non-null  object
#  9   PRIORIDAD                          13026 non-null  object
#  10  RECEPCION                          13026 non-null  object
# dtypes: int64(1), object(10)
# ...

# %%
# Manipulacion de fechas tipo datetime
col = 'FECHA_INICIO_DESPLAZAMIENTO_MOVIL'
data[col].max()
# Out:
# '2022-08-08 11:23:01'

# %%
#aplicar filtros
val_min = data[col].min()
data[data[col] == val_min] # aplico el filtro
# Out:
#       NUMERO_INCIDENTE FECHA_INICIO_DESPLAZAMIENTO_MOVIL  CODIGO_LOCALIDAD  \
# 13054  CRU-00312775-22               0000-00-00 00:00:00                 9
#
#       LOCALIDAD      EDAD    UNIDAD    GENERO            RED  \
# 13054  Fontib¢n  SIN_DATO  SIN_DATO  SIN_DATO  Sur Occidente
#
#                    TIPO_INCIDENTE PRIORIDAD            RECEPCION
# 13054  Accidente Cerebro Vascular      ALTA  0000-00-00 00:00:00

# %%
data[data[col] != val_min]
# Out:
#       NUMERO_INCIDENTE FECHA_INICIO_DESPLAZAMIENTO_MOVIL  CODIGO_LOCALIDAD  \
# 0      CRU-00278353-22               2022-07-01 00:08:59                11
# 1      CRU-00278360-22               2022-07-01 00:14:58                11
# 2      CRU-00278365-22               2022-07-01 00:21:59                18
# 3      CRU-00278370-22               2022-07-01 00:38:38                19
# 4      CRU-00278372-22               2022-07-01 00:53:32                 1
# ...                ...                               ...               ...
# 13049  CRU-00314021-22               2022-08-02 03:25:08                14
# 13050  CRU-00314021-22               2022-08-08 05:31:48                14
# 13051  CRU-00314021-22               2022-08-08 10:38:32                14
# 13052  CRU-00314021-22               2022-08-08 11:23:01                10
# 13053  CRU-00314021-22               2022-08-08 11:23:01                10
#
# ...

# %%
# Formato de fechas (datetime)

data[col] = pd.to_datetime(data[col], errors='coerce') #

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13026 entries, 0 to 13054
# Data columns (total 11 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   NUMERO_INCIDENTE                   13026 non-null  object
#  1   FECHA_INICIO_DESPLAZAMIENTO_MOVIL  13025 non-null  datetime64[ns]
#  2   CODIGO_LOCALIDAD                   13026 non-null  int64
#  3   LOCALIDAD                          13026 non-null  object
#  4   EDAD                               13026 non-null  object
#  5   UNIDAD                             13026 non-null  object
#  6   GENERO                             13026 non-null  object
#  7   RED                                13026 non-null  object
#  8   TIPO_INCIDENTE                     13026 non-null  object
#  9   PRIORIDAD                          13026 non-null  object
#  10  RECEPCION                          13026 non-null  object
# ...

# %%
data['RECEPCION']
# Out:
# 0        2022-07-01 03:40:13
# 1        2022-07-01 03:38:13
# 2        2022-07-01 04:08:24
# 3        0000-00-00 00:00:00
# 4        2022-07-01 03:25:29
#                 ...
# 13050         8/08/2022 6:48
# 13051    0000-00-00 00:00:00
# 13052        9/08/2022 13:13
# 13053    0000-00-00 00:00:00
# 13054    0000-00-00 00:00:00
# Name: RECEPCION, Length: 13026, dtype: object

# %%
from dateutil.parser import parse

parse('08/02/2022')

#pd.to_datetime(data['RECEPCION'], errors='coerce', format='%Y-%m-%d %H:%M:%S')
# Out:
# datetime.datetime(2022, 8, 2, 0, 0)

# %%
parse('08/02/2022 5:30 pm')
# Out:
# datetime.datetime(2022, 8, 2, 17, 30)

# %%
pd.to_datetime(parse(data['RECEPCION'][13052], dayfirst=False))
# Out:
# Timestamp('2022-09-08 13:13:00')

# %%
# Una función que reciba un string, con fechas y regrese un valor en datetime usando parse
def convertir_formato_fecha(str_fecha):
    val_datetime = parse(str_fecha, dayfirst=False)
    return val_datetime

# %%
data = data.reset_index()

# %%
lista_fechas = list()
n_filas = data.shape[0] 
#n_filas = len(data['RECEPCION'])
for i in range(0, n_filas):

    str_fecha = data['RECEPCION'][i]

    try:
        
        val_datetime = convertir_formato_fecha(str_fecha=str_fecha)
        lista_fechas.append(val_datetime)
    except Exception as e:
        print(i, e)
        lista_fechas.append(str_fecha)
        continue
# Out:
# 3 year 0 is out of range: 0000-00-00 00:00:00
# 5 year 0 is out of range: 0000-00-00 00:00:00
# 9 year 0 is out of range: 0000-00-00 00:00:00
# 11 year 0 is out of range: 0000-00-00 00:00:00
# 13 year 0 is out of range: 0000-00-00 00:00:00
# 16 year 0 is out of range: 0000-00-00 00:00:00
# 19 year 0 is out of range: 0000-00-00 00:00:00
# 21 year 0 is out of range: 0000-00-00 00:00:00
# 23 year 0 is out of range: 0000-00-00 00:00:00
# 24 year 0 is out of range: 0000-00-00 00:00:00
# 27 year 0 is out of range: 0000-00-00 00:00:00
# 29 year 0 is out of range: 0000-00-00 00:00:00
# 30 year 0 is out of range: 0000-00-00 00:00:00
# 31 year 0 is out of range: 0000-00-00 00:00:00
# 32 year 0 is out of range: 0000-00-00 00:00:00
# 35 year 0 is out of range: 0000-00-00 00:00:00
# 36 year 0 is out of range: 0000-00-00 00:00:00
# 38 year 0 is out of range: 0000-00-00 00:00:00
# 42 year 0 is out of range: 0000-00-00 00:00:00
# 45 year 0 is out of range: 0000-00-00 00:00:00
# ...

# %%
data['RECEPCION_CORREGIDA'] = lista_fechas

# %%
data['RECEPCION_CORREGIDA'] = pd.to_datetime(data['RECEPCION_CORREGIDA'], errors='coerce')

# %%
data
# Out:
#        index NUMERO_INCIDENTE FECHA_INICIO_DESPLAZAMIENTO_MOVIL  \
# 0          0  CRU-00278353-22               2022-07-01 00:08:59
# 1          1  CRU-00278360-22               2022-07-01 00:14:58
# 2          2  CRU-00278365-22               2022-07-01 00:21:59
# 3          3  CRU-00278370-22               2022-07-01 00:38:38
# 4          4  CRU-00278372-22               2022-07-01 00:53:32
# ...      ...              ...                               ...
# 13021  13050  CRU-00314021-22               2022-08-08 05:31:48
# 13022  13051  CRU-00314021-22               2022-08-08 10:38:32
# 13023  13052  CRU-00314021-22               2022-08-08 11:23:01
# 13024  13053  CRU-00314021-22               2022-08-08 11:23:01
# 13025  13054  CRU-00312775-22                               NaT
#
#        CODIGO_LOCALIDAD           LOCALIDAD      EDAD    UNIDAD     GENERO  \
# 0                    11                Suba        88      A¤os   FEMENINO
# ...

# %% [markdown]
# # Consistencia de los datos

# %%
data['EDAD'].value_counts(dropna=False)
# Out:
# SIN_DATO    6187
# 23           150
# 22           140
# 27           134
# 30           134
#             ...
# 7             17
# 98            16
# 9             15
# 8             14
# 97            12
# Name: EDAD, Length: 100, dtype: int64

# %%
# reemplazar SIN_DATO por unn valor nulo de tipo numerico
#data['EDAD'].REPLACE({'SIN_DATO' : np.nan}).value_counts(dropna=False)
data['EDAD']=data['EDAD'].replace({'SIN_DATO' : np.nan})

# %%
#Funciones lambda

#x = np.nan
x='5'
f = lambda x: x if pd.isna(x) == True else int(x)

f(x)
# Out:
# 5

# %%
data['EDAD']=data['EDAD'].apply(f)
# Out:
# 0        88.0
# 1        16.0
# 2        52.0
# 3         NaN
# 4        33.0
#          ...
# 13021    18.0
# 13022     NaN
# 13023    11.0
# 13024    19.0
# 13025     NaN
# Name: EDAD, Length: 13026, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13026 entries, 0 to 13025
# Data columns (total 13 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   index                              13026 non-null  int64
#  1   NUMERO_INCIDENTE                   13026 non-null  object
#  2   FECHA_INICIO_DESPLAZAMIENTO_MOVIL  13025 non-null  datetime64[ns]
#  3   CODIGO_LOCALIDAD                   13026 non-null  int64
#  4   LOCALIDAD                          13026 non-null  object
#  5   EDAD                               6839 non-null   object
#  6   UNIDAD                             13026 non-null  object
#  7   GENERO                             13026 non-null  object
#  8   RED                                13026 non-null  object
#  9   TIPO_INCIDENTE                     13026 non-null  object
#  10  PRIORIDAD                          13026 non-null  object
# ...

# %%
#Ejemplo dejarlo en minuscula
word = 'BigData'
print(word, word.lower())
# Out:
# BigData bigdata

# %%
data['LOCALIDAD'].apply(lambda x: x.lstrip()).value_counts()
# Out:
# Kennedy               1740
# Suba                  1323
# Engativ               1304
# Bosa                  1065
# Ciudad Bol¡var        1009
# Puente Aranda          742
# Fontib¢n               670
# Usaqun                667
# Rafael Uribe Uribe     601
# Usme                   597
# San Crist¢bal          595
# Chapinero              507
# Tunjuelito             391
# Barrios Unidos         389
# Los M rtires           379
# Teusaquillo            361
# Santa Fe               356
# Antonio Nari¤o         244
# La Candelaria           85
# Sumapaz                  1
# Name: LOCALIDAD, dtype: int64

# %%
#Tarea
#recibe el archivo llmadas 123
#transforme
#mande el archivo nuevo y lo pegue en la carpeta proccess
